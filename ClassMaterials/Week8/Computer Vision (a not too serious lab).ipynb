# %% [markdown]
# # Computer Vision (a not too serious lab) 8dec

# %% [markdown]
# ### [Artificial intelligence turns racist after learning from humans](https://metro.co.uk/2021/11/10/artificial-intelligence-turns-racist-after-learning-from-humans-15575220/)
# _________
#
# ### [Ethical AI movement aims for more accountability to decrease algorithmic bias](https://www.emarketer.com/content/ethical-ai-movement-aims-more-accountability-decrease-algorithmic-bias)
# ________

# %% [markdown]
# - Sadly much like society it will take generations to flush out the old bias that exists in both society and our systems and structures that we have in place.
# - On the plus side maybe the rate of rapid advancements and speed that wee are witnessing in cloud computing, might also be able to detect these bias (racist) traits even faster.
# - But then again relying on a technology to fix an existing bias is not necessarily a convincing future.
# - Maybe the answer lies in examples such as, Twitter's “bias bounty” program that offers researchers prizes for correctly identifying instances of bias in its image-cropping algorithm.

# %%
# %matplotlib inline
from IPython.display import Image
Image('/Users/AFROARC/Documents/GitHub/BCNDATA1021/ClassMaterials/Week8/download.png')

# %%
print("A large clock tower on a hill")
# Out:
# A large clock tower on a hill

# %%
Image('/Users/AFROARC/Documents/GitHub/BCNDATA1021/ClassMaterials/Week8/download (1).png')

# %%
Print("A clock tower on a cliff")

# %% [markdown]
# ## comments

# %% [markdown]
# - i think there is a nit more time to go in these algorythms
# - but i do like the abract forms
# - looks like something out of Mad Max or Water World

# %% [markdown]
# # [Dogs vs Cats!]('https://thedatafrog.com/en/articles/dogs-vs-cats/')

# %% [markdown]
# ## image processing

# %% [markdown]
# ###### l'll have a go. So from my simplistic understanding of the process, it involves the way in which images are transformed to better be read/analysed by the model. It is in essence a set of operations that break down the image into the best format for the computer to both read and  interpret.
# ###### In the case of the cats vs dogs example it would be the breaking down of the images into pixels  and forming relationships or classifications between sarrounding shapes and from, both in close proximity and across the entire image.
